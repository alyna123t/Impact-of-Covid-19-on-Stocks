# %% [markdown]
# #Sectors and stock info

# %%
import yfinance as yf

# Define stock tickers
stocks = {
"Food/Restaurant": ["MCD", "SBUX", "CMG", "YUM", "DPZ"],
"Construction": ["CAT", "DE", "NUE", "VMC", "MLM"],
"Tech": ["AAPL", "MSFT", "GOOGL", "NVDA", "META"],
"Property": ["SPG", "AMT", "PLD", "EQIX", "PSA"],
"Medical" : ["VHT"],
"Market" : ["^GSPC"],
"Transport" : ["DAL", "UBER", "LYFT"],
}

# Fetch data for each sector
for sector, tickers in stocks.items():
  print(f"\n{sector} Sector:")
  for ticker in tickers:
    stock = yf.Ticker(ticker)
    info = stock.info
    print(info)
# Out:
# Food/Restaurant Sector:
# ...

# %% [markdown]
# #Comparisons

# %% [markdown]
# ##Food/restaurant

# %% [markdown]
# ###Prices

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame

start_date = '2020-01-01'
end_date = '2022-01-01'

stock_name_1 = "MCD"

stock_name_2 = "SBUX"

stock_name_3 = "CMG"

stock_name_4 = "YUM"

stock_name_5 = "DPZ"


# def get_close_price_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Close']

def get_close_price_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    close_prices = stock_data['Close']

    # Normalize the close prices to be between 0 and 1
    min_price = close_prices.min()
    max_price = close_prices.max()
    normalized_close_prices = (close_prices - min_price) / (max_price - min_price)

    return normalized_close_prices

stock_1_cp=get_close_price_data(stock_name_1, start_date, end_date)
stock_2_cp=get_close_price_data(stock_name_2, start_date, end_date)
stock_3_cp=get_close_price_data(stock_name_3, start_date, end_date)
stock_4_cp=get_close_price_data(stock_name_4, start_date, end_date)
stock_5_cp=get_close_price_data(stock_name_5, start_date, end_date)


results1 = DataFrame({'McDonalds': stock_1_cp,
                      'Starbucks': stock_2_cp,
                      'Chipotle': stock_3_cp,
                      'Yum! Brands, Inc.': stock_4_cp,
                      'Dominos Pizza, Inc.': stock_5_cp})

results1.plot(figsize=(12,6))
#plt.figure(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"Food/Restaurant Industry Price History")
plt.ylabel("Price (USD)")
plt.show()

# def get_vol_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Volume']

def get_vol_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    volume = stock_data['Volume']

    # Normalize the close prices to be between 0 and 1
    min_price = volume.min()
    max_price = volume.max()
    normalized_volume = (volume - min_price) / (max_price - min_price)

    return normalized_volume


stock_1_vl=get_vol_data(stock_name_1, start_date, end_date)
stock_2_vl=get_vol_data(stock_name_2, start_date, end_date)
stock_3_vl=get_vol_data(stock_name_3, start_date, end_date)
stock_4_vl=get_vol_data(stock_name_4, start_date, end_date)
stock_5_vl=get_vol_data(stock_name_5, start_date, end_date)

results1 = DataFrame({'McDonalds': stock_1_vl,
                      'Starbucks': stock_2_vl,
                      'Chipotle': stock_3_vl,
                      'Yum! Brands, Inc.': stock_4_vl,
                      'Dominos Pizza, Inc.': stock_5_vl})

results1.plot(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"Food/Restaurant Industry Volume History")
plt.ylabel("Price (USD)")
plt.show()



def std_dev_cp(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Close'].resample('1M').std()

stock_1_stdcp=std_dev_cp(stock_name_1, start_date, end_date)
stock_2_stdcp=std_dev_cp(stock_name_2, start_date, end_date)
stock_3_stdcp=std_dev_cp(stock_name_3, start_date, end_date)
stock_4_stdcp=std_dev_cp(stock_name_4, start_date, end_date)
stock_5_stdcp=std_dev_cp(stock_name_5, start_date, end_date)

results1 = DataFrame({'McDonalds': stock_1_stdcp,
                      'Starbucks': stock_2_stdcp,
                      'Chipotle': stock_3_stdcp,
                      'Yum! Brands, Inc.': stock_4_stdcp,
                      'Dominos Pizza, Inc.': stock_5_stdcp})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"Food/Restaurant Industry Price Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()


def std_dev_vl(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Volume'].resample('1M').std()

stock_1_stdvl=std_dev_vl(stock_name_1, start_date, end_date)
stock_2_stdvl=std_dev_vl(stock_name_2, start_date, end_date)
stock_3_stdvl=std_dev_vl(stock_name_3, start_date, end_date)
stock_4_stdvl=std_dev_vl(stock_name_4, start_date, end_date)
stock_5_stdvl=std_dev_vl(stock_name_5, start_date, end_date)

results1 = DataFrame({'McDonalds': stock_1_stdvl,
                      'Starbucks': stock_2_stdvl,
                      'Chipotle': stock_3_stdvl,
                      'Yum! Brands, Inc.': stock_4_stdvl,
                      'Dominos Pizza, Inc.': stock_5_stdvl})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"Food/Restaurant Industry Volume Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# ##Construction Sector

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame


industry_name = "Construction Industry"
start_date = '2020-01-01'
end_date = '2022-01-01'

stock_name_1 = "CAT"

stock_name_2 = "DE"

stock_name_3 = "NUE"

stock_name_4 = "VMC"

stock_name_5 = "MLM"


# def get_close_price_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Close']

def get_close_price_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    close_prices = stock_data['Close']

    # Normalize the close prices to be between 0 and 1
    min_price = close_prices.min()
    max_price = close_prices.max()
    normalized_close_prices = (close_prices - min_price) / (max_price - min_price)

    return normalized_close_prices

stock_1_cp=get_close_price_data(stock_name_1, start_date, end_date)
stock_2_cp=get_close_price_data(stock_name_2, start_date, end_date)
stock_3_cp=get_close_price_data(stock_name_3, start_date, end_date)
stock_4_cp=get_close_price_data(stock_name_4, start_date, end_date)
stock_5_cp=get_close_price_data(stock_name_5, start_date, end_date)


results1 = DataFrame({'Catepillar Inc.': stock_1_cp,
                      'Deere & Company': stock_2_cp,
                      'Nucor Corporation': stock_3_cp,
                      'Vulcan Material Company': stock_4_cp,
                      'Martin Marietta Materials, Inc.': stock_5_cp})

results1.plot(figsize=(12,6))
#plt.figure(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Price History")
plt.ylabel("Price (USD)")
plt.show()

# def get_vol_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Volume']

def get_vol_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    volume = stock_data['Volume']

    # Normalize the close prices to be between 0 and 1
    min_price = volume.min()
    max_price = volume.max()
    normalized_volume = (volume - min_price) / (max_price - min_price)

    return normalized_volume


stock_1_vl=get_vol_data(stock_name_1, start_date, end_date)
stock_2_vl=get_vol_data(stock_name_2, start_date, end_date)
stock_3_vl=get_vol_data(stock_name_3, start_date, end_date)
stock_4_vl=get_vol_data(stock_name_4, start_date, end_date)
stock_5_vl=get_vol_data(stock_name_5, start_date, end_date)

results1 = DataFrame({'Catepillar Inc.': stock_1_vl,
                      'Deere & Company': stock_2_vl,
                      'Nucor Corporation': stock_3_vl,
                      'Vulcan Material Company': stock_4_vl,
                      'Martin Marietta Materials, Inc.': stock_5_vl})

results1.plot(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume History")
plt.ylabel("Price (USD)")
plt.show()



def std_dev_cp(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Close'].resample('1M').std()

stock_1_stdcp=std_dev_cp(stock_name_1, start_date, end_date)
stock_2_stdcp=std_dev_cp(stock_name_2, start_date, end_date)
stock_3_stdcp=std_dev_cp(stock_name_3, start_date, end_date)
stock_4_stdcp=std_dev_cp(stock_name_4, start_date, end_date)
stock_5_stdcp=std_dev_cp(stock_name_5, start_date, end_date)

results1 = DataFrame({'Catepillar Inc.': stock_1_stdcp,
                      'Deere & Company': stock_2_stdcp,
                      'Nucor Corporation': stock_3_stdcp,
                      'Vulcan Material Company': stock_4_stdcp,
                      'Martin Marietta Materials, Inc.': stock_5_stdcp})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Price Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()


def std_dev_vl(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Volume'].resample('1M').std()

stock_1_stdvl=std_dev_vl(stock_name_1, start_date, end_date)
stock_2_stdvl=std_dev_vl(stock_name_2, start_date, end_date)
stock_3_stdvl=std_dev_vl(stock_name_3, start_date, end_date)
stock_4_stdvl=std_dev_vl(stock_name_4, start_date, end_date)
stock_5_stdvl=std_dev_vl(stock_name_5, start_date, end_date)

results1 = DataFrame({'Catepillar Inc.': stock_1_stdvl,
                      'Deere & Company': stock_2_stdvl,
                      'Nucor Corporation': stock_3_stdvl,
                      'Vulcan Material Company': stock_4_stdvl,
                      'Martin Marietta Materials, Inc.': stock_5_stdvl})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# ##Tech Sector

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame


industry_name = "Tech Industry"
start_date = '2020-01-01'
end_date = '2022-01-01'

stock_name_1 = "AAPL"

stock_name_2 = "MSFT"

stock_name_3 = "GOOGL"

stock_name_4 = "NVDA"

stock_name_5 = "META"


# def get_close_price_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Close']

def get_close_price_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    close_prices = stock_data['Close']

    # Normalize the close prices to be between 0 and 1
    min_price = close_prices.min()
    max_price = close_prices.max()
    normalized_close_prices = (close_prices - min_price) / (max_price - min_price)

    return normalized_close_prices

stock_1_cp=get_close_price_data(stock_name_1, start_date, end_date)
stock_2_cp=get_close_price_data(stock_name_2, start_date, end_date)
stock_3_cp=get_close_price_data(stock_name_3, start_date, end_date)
stock_4_cp=get_close_price_data(stock_name_4, start_date, end_date)
stock_5_cp=get_close_price_data(stock_name_5, start_date, end_date)


results1 = DataFrame({'Apple Inc.': stock_1_cp,
                      'Microsoft Corporation': stock_2_cp,
                      'Alphabet Inc.': stock_3_cp,
                      'NVIDIA Corporation': stock_4_cp,
                      'Meta Platforms, Inc.': stock_5_cp})

results1.plot(figsize=(12,6))
#plt.figure(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Price History")
plt.ylabel("Price (USD)")
plt.show()

# def get_vol_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Volume']

def get_vol_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    volume = stock_data['Volume']

    # Normalize the close prices to be between 0 and 1
    min_price = volume.min()
    max_price = volume.max()
    normalized_volume = (volume - min_price) / (max_price - min_price)

    return normalized_volume


stock_1_vl=get_vol_data(stock_name_1, start_date, end_date)
stock_2_vl=get_vol_data(stock_name_2, start_date, end_date)
stock_3_vl=get_vol_data(stock_name_3, start_date, end_date)
stock_4_vl=get_vol_data(stock_name_4, start_date, end_date)
stock_5_vl=get_vol_data(stock_name_5, start_date, end_date)

results1 = DataFrame({'Apple Inc.': stock_1_vl,
                      'Microsoft Corporation': stock_2_vl,
                      'Alphabet Inc.': stock_3_vl,
                      'NVIDIA Corporation': stock_4_vl,
                      'Meta Platforms, Inc.': stock_5_vl})

results1.plot(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume History")
plt.ylabel("Price (USD)")
plt.show()



def std_dev_cp(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Close'].resample('1M').std()

stock_1_stdcp=std_dev_cp(stock_name_1, start_date, end_date)
stock_2_stdcp=std_dev_cp(stock_name_2, start_date, end_date)
stock_3_stdcp=std_dev_cp(stock_name_3, start_date, end_date)
stock_4_stdcp=std_dev_cp(stock_name_4, start_date, end_date)
stock_5_stdcp=std_dev_cp(stock_name_5, start_date, end_date)

results1 = DataFrame({'Apple Inc.': stock_1_stdcp,
                      'Microsoft Corporation': stock_2_stdcp,
                      'Alphabet Inc.': stock_3_stdcp,
                      'NVIDIA Corporation': stock_4_stdcp,
                      'Meta Platforms, Inc.': stock_5_stdcp})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Price Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()


def std_dev_vl(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Volume'].resample('1M').std()

stock_1_stdvl=std_dev_vl(stock_name_1, start_date, end_date)
stock_2_stdvl=std_dev_vl(stock_name_2, start_date, end_date)
stock_3_stdvl=std_dev_vl(stock_name_3, start_date, end_date)
stock_4_stdvl=std_dev_vl(stock_name_4, start_date, end_date)
stock_5_stdvl=std_dev_vl(stock_name_5, start_date, end_date)

results1 = DataFrame({'Apple Inc.': stock_1_stdvl,
                      'Microsoft Corporation': stock_2_stdvl,
                      'Alphabet Inc.': stock_3_stdvl,
                      'NVIDIA Corporation': stock_4_stdvl,
                      'Meta Platforms, Inc.': stock_5_stdvl})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# ##Property Sector

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame


industry_name = "Property Industry"
start_date = '2020-01-01'
end_date = '2022-01-01'

stock_name_1 = "SPG"

stock_name_2 = "AMT"

stock_name_3 = "PLD"

stock_name_4 = "EQIX"

stock_name_5 = "PSA"


# def get_close_price_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Close']

def get_close_price_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    close_prices = stock_data['Close']

    # Normalize the close prices to be between 0 and 1
    min_price = close_prices.min()
    max_price = close_prices.max()
    normalized_close_prices = (close_prices - min_price) / (max_price - min_price)

    return normalized_close_prices

stock_1_cp=get_close_price_data(stock_name_1, start_date, end_date)
stock_2_cp=get_close_price_data(stock_name_2, start_date, end_date)
stock_3_cp=get_close_price_data(stock_name_3, start_date, end_date)
stock_4_cp=get_close_price_data(stock_name_4, start_date, end_date)
stock_5_cp=get_close_price_data(stock_name_5, start_date, end_date)


results1 = DataFrame({'Simon Property Group, Inc.': stock_1_cp,
                      'American Tower Corporation': stock_2_cp,
                      'Prologis, Inc.': stock_3_cp,
                      'Equinix, Inc.': stock_4_cp,
                      'Public Storage': stock_5_cp})

results1.plot(figsize=(12,6))
#plt.figure(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Price History")
plt.ylabel("Price (USD)")
plt.show()

# def get_vol_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Volume']

def get_vol_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    volume = stock_data['Volume']

    # Normalize the close prices to be between 0 and 1
    min_price = volume.min()
    max_price = volume.max()
    normalized_volume = (volume - min_price) / (max_price - min_price)

    return normalized_volume


stock_1_vl=get_vol_data(stock_name_1, start_date, end_date)
stock_2_vl=get_vol_data(stock_name_2, start_date, end_date)
stock_3_vl=get_vol_data(stock_name_3, start_date, end_date)
stock_4_vl=get_vol_data(stock_name_4, start_date, end_date)
stock_5_vl=get_vol_data(stock_name_5, start_date, end_date)

results1 = DataFrame({'Simon Property Group, Inc.': stock_1_vl,
                      'American Tower Corporation': stock_2_vl,
                      'Prologis, Inc.': stock_3_vl,
                      'Equinix, Inc.': stock_4_vl,
                      'Public Storage': stock_5_vl})

results1.plot(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume History")
plt.ylabel("Price (USD)")
plt.show()



def std_dev_cp(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Close'].resample('1M').std()

stock_1_stdcp=std_dev_cp(stock_name_1, start_date, end_date)
stock_2_stdcp=std_dev_cp(stock_name_2, start_date, end_date)
stock_3_stdcp=std_dev_cp(stock_name_3, start_date, end_date)
stock_4_stdcp=std_dev_cp(stock_name_4, start_date, end_date)
stock_5_stdcp=std_dev_cp(stock_name_5, start_date, end_date)

results1 = DataFrame({'Simon Property Group, Inc.': stock_1_stdcp,
                      'American Tower Corporation': stock_2_stdcp,
                      'Prologis, Inc.': stock_3_stdcp,
                      'Equinix, Inc.': stock_4_stdcp,
                      'Public Storage': stock_5_stdcp})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Price Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()


def std_dev_vl(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Volume'].resample('1M').std()

stock_1_stdvl=std_dev_vl(stock_name_1, start_date, end_date)
stock_2_stdvl=std_dev_vl(stock_name_2, start_date, end_date)
stock_3_stdvl=std_dev_vl(stock_name_3, start_date, end_date)
stock_4_stdvl=std_dev_vl(stock_name_4, start_date, end_date)
stock_5_stdvl=std_dev_vl(stock_name_5, start_date, end_date)

results1 = DataFrame({'Simon Property Group, Inc.': stock_1_stdvl,
                      'American Tower Corporation': stock_2_stdvl,
                      'Prologis, Inc.': stock_3_stdvl,
                      'Equinix, Inc.': stock_4_stdvl,
                      'Public Storage': stock_5_stdvl})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# ##Healthcare Sector

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame


industry_name = "Healthcare Industry"
start_date = '2020-01-01'
end_date = '2022-01-01'

stock_name_1 = "JNJ"

stock_name_2 = "PFE"

stock_name_3 = "MRK"

stock_name_4 = "ABT"

stock_name_5 = "UNH"


# def get_close_price_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Close']

def get_close_price_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    close_prices = stock_data['Close']

    # Normalize the close prices to be between 0 and 1
    min_price = close_prices.min()
    max_price = close_prices.max()
    normalized_close_prices = (close_prices - min_price) / (max_price - min_price)

    return normalized_close_prices

stock_1_cp=get_close_price_data(stock_name_1, start_date, end_date)
stock_2_cp=get_close_price_data(stock_name_2, start_date, end_date)
stock_3_cp=get_close_price_data(stock_name_3, start_date, end_date)
stock_4_cp=get_close_price_data(stock_name_4, start_date, end_date)
stock_5_cp=get_close_price_data(stock_name_5, start_date, end_date)


results1 = DataFrame({'Johnson & Johnson': stock_1_cp,
                      'Pfizer Inc.': stock_2_cp,
                      'Merck & Co., Inc.': stock_3_cp,
                      'Abbott Laboratories': stock_4_cp,
                      'UnitedHealth Group Incorporated': stock_5_cp})

results1.plot(figsize=(12,6))
#plt.figure(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Price History")
plt.ylabel("Price (USD)")
plt.show()

# def get_vol_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Volume']

def get_vol_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    volume = stock_data['Volume']

    # Normalize the close prices to be between 0 and 1
    min_price = volume.min()
    max_price = volume.max()
    normalized_volume = (volume - min_price) / (max_price - min_price)

    return normalized_volume


stock_1_vl=get_vol_data(stock_name_1, start_date, end_date)
stock_2_vl=get_vol_data(stock_name_2, start_date, end_date)
stock_3_vl=get_vol_data(stock_name_3, start_date, end_date)
stock_4_vl=get_vol_data(stock_name_4, start_date, end_date)
stock_5_vl=get_vol_data(stock_name_5, start_date, end_date)

results1 = DataFrame({'Johnson & Johnson': stock_1_vl,
                      'Pfizer Inc.': stock_2_vl,
                      'Merck & Co., Inc.': stock_3_vl,
                      'Abbott Laboratories': stock_4_vl,
                      'UnitedHealth Group Incorporated': stock_5_vl})

results1.plot(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume History")
plt.ylabel("Price (USD)")
plt.show()



def std_dev_cp(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Close'].resample('1M').std()

stock_1_stdcp=std_dev_cp(stock_name_1, start_date, end_date)
stock_2_stdcp=std_dev_cp(stock_name_2, start_date, end_date)
stock_3_stdcp=std_dev_cp(stock_name_3, start_date, end_date)
stock_4_stdcp=std_dev_cp(stock_name_4, start_date, end_date)
stock_5_stdcp=std_dev_cp(stock_name_5, start_date, end_date)

results1 = DataFrame({'Johnson & Johnson': stock_1_stdcp,
                      'Pfizer Inc.': stock_2_stdcp,
                      'Merck & Co., Inc.': stock_3_stdcp,
                      'Abbott Laboratories': stock_4_stdcp,
                      'UnitedHealth Group Incorporated': stock_5_stdcp})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Price Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()


def std_dev_vl(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Volume'].resample('1M').std()

stock_1_stdvl=std_dev_vl(stock_name_1, start_date, end_date)
stock_2_stdvl=std_dev_vl(stock_name_2, start_date, end_date)
stock_3_stdvl=std_dev_vl(stock_name_3, start_date, end_date)
stock_4_stdvl=std_dev_vl(stock_name_4, start_date, end_date)
stock_5_stdvl=std_dev_vl(stock_name_5, start_date, end_date)

results1 = DataFrame({'Johnson & Johnson': stock_1_stdvl,
                      'Pfizer Inc.': stock_2_stdvl,
                      'Merck & Co., Inc.': stock_3_stdvl,
                      'Abbott Laboratories': stock_4_stdvl,
                      'UnitedHealth Group Incorporated': stock_5_stdvl})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()

# %% [markdown]
# ##Transport

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from pandas import DataFrame


industry_name = "Transport Industry"
start_date = '2020-01-01'
end_date = '2022-01-01'

stock_name_1 = "UNP"

stock_name_2 = "FDX"

stock_name_3 = "DAL"

stock_name_4 = "AAL"

stock_name_5 = "UBER"


# def get_close_price_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Close']

def get_close_price_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    close_prices = stock_data['Close']

    # Normalize the close prices to be between 0 and 1
    min_price = close_prices.min()
    max_price = close_prices.max()
    normalized_close_prices = (close_prices - min_price) / (max_price - min_price)

    return normalized_close_prices

stock_1_cp=get_close_price_data(stock_name_1, start_date, end_date)
stock_2_cp=get_close_price_data(stock_name_2, start_date, end_date)
stock_3_cp=get_close_price_data(stock_name_3, start_date, end_date)
stock_4_cp=get_close_price_data(stock_name_4, start_date, end_date)
stock_5_cp=get_close_price_data(stock_name_5, start_date, end_date)


results1 = DataFrame({'Union Pacific Corporation': stock_1_cp,
                      'FedEx Corporation': stock_2_cp,
                      'Delta Air Lines': stock_3_cp,
                      'American Airlines Group Inc.': stock_4_cp,
                      'Uber Technologies, Inc.': stock_5_cp})

results1.plot(figsize=(12,6))
#plt.figure(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Price History")
plt.ylabel("Price (USD)")
plt.show()

# def get_vol_data(stock_name, start_date, end_date):
#   ticker_2 = yf.Ticker(stock_name)
#   stock_data_2 = ticker_2.history(start=start_date, end=end_date)
#   return stock_data_2['Volume']

def get_vol_data(stock_name, start_date, end_date):
    ticker = yf.Ticker(stock_name)
    stock_data = ticker.history(start=start_date, end=end_date)
    volume = stock_data['Volume']

    # Normalize the close prices to be between 0 and 1
    min_price = volume.min()
    max_price = volume.max()
    normalized_volume = (volume - min_price) / (max_price - min_price)

    return normalized_volume


stock_1_vl=get_vol_data(stock_name_1, start_date, end_date)
stock_2_vl=get_vol_data(stock_name_2, start_date, end_date)
stock_3_vl=get_vol_data(stock_name_3, start_date, end_date)
stock_4_vl=get_vol_data(stock_name_4, start_date, end_date)
stock_5_vl=get_vol_data(stock_name_5, start_date, end_date)

results1 = DataFrame({'Union Pacific Corporation': stock_1_vl,
                      'FedEx Corporation': stock_2_vl,
                      'Delta Air Lines': stock_3_vl,
                      'American Airlines Group Inc.': stock_4_vl,
                      'Uber Technologies, Inc.': stock_5_vl})

results1.plot(figsize=(12,6))
plt.legend(loc='upper left')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume History")
plt.ylabel("Price (USD)")
plt.show()



def std_dev_cp(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Close'].resample('1M').std()

stock_1_stdcp=std_dev_cp(stock_name_1, start_date, end_date)
stock_2_stdcp=std_dev_cp(stock_name_2, start_date, end_date)
stock_3_stdcp=std_dev_cp(stock_name_3, start_date, end_date)
stock_4_stdcp=std_dev_cp(stock_name_4, start_date, end_date)
stock_5_stdcp=std_dev_cp(stock_name_5, start_date, end_date)

results1 = DataFrame({'Union Pacific Corporation': stock_1_stdcp,
                      'FedEx Corporation': stock_2_stdcp,
                      'Delta Air Lines': stock_3_stdcp,
                      'American Airlines Group Inc.': stock_4_stdcp,
                      'Uber Technologies, Inc.': stock_5_stdcp})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Price Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()


def std_dev_vl(stock_name, start_date, end_date):
  ticker_1 = yf.Ticker(stock_name)
  stock_data_1 = ticker_1.history(start=start_date, end=end_date)
  return stock_data_1['Volume'].resample('1M').std()

stock_1_stdvl=std_dev_vl(stock_name_1, start_date, end_date)
stock_2_stdvl=std_dev_vl(stock_name_2, start_date, end_date)
stock_3_stdvl=std_dev_vl(stock_name_3, start_date, end_date)
stock_4_stdvl=std_dev_vl(stock_name_4, start_date, end_date)
stock_5_stdvl=std_dev_vl(stock_name_5, start_date, end_date)

results1 = DataFrame({'Union Pacific Corporation': stock_1_stdvl,
                      'FedEx Corporation': stock_2_stdvl,
                      'Delta Air Lines': stock_3_stdvl,
                      'American Airlines Group Inc.': stock_4_stdvl,
                      'Uber Technologies, Inc.': stock_5_stdvl})

results1.plot()
plt.legend(loc='upper right')
plt.xlabel("Month")
plt.title(f"{industry_name} Volume Standard Deviation")
plt.ylabel("Price (USD)")
plt.show()
